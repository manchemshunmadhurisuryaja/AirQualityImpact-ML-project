# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('AirQualityDS.csv')

# %%
df.shape
# Out:
# (27874, 43)

# %%
df.head(10)
# Out:
#                country     location_name  latitude  longitude  \
# 0          Afghanistan             Kabul     34.52      69.18
# 1              Albania            Tirana     41.33      19.82
# 2              Algeria           Algiers     36.76       3.05
# 3              Andorra  Andorra La Vella     42.50       1.52
# 4               Angola            Luanda     -8.84      13.23
# 5  Antigua and Barbuda      Saint John's     17.12     -61.85
# 6            Argentina      Buenos Aires    -34.59     -58.67
# 7              Armenia           Yerevan     40.18      44.51
# 8            Australia          Canberra    -35.28     149.22
# 9              Austria            Vienna     48.20      16.37
#
#                          timezone  last_updated_epoch      last_updated  \
# 0                      Asia/Kabul          1693301400  29-08-2023 14:00
# 1                   Europe/Tirane          1693301400  29-08-2023 11:30
# 2                  Africa/Algiers          1693301400  29-08-2023 10:30
# 3                  Europe/Andorra          1693301400  29-08-2023 11:30
# 4                   Africa/Luanda          1693301400  29-08-2023 10:30
# 5                 America/Antigua          1693301400  29-08-2023 05:30
# 6  America/Argentina/Buenos_Aires          1693301400  29-08-2023 06:30
# 7                    Asia/Yerevan          1693301400  29-08-2023 13:30
# 8                Australia/Sydney          1693301400  29-08-2023 19:30
# 9                   Europe/Vienna          1693301400  29-08-2023 11:30
#
#    temperature_celsius  temperature_fahrenheit condition_text  ...  \
# 0                 28.8                    83.8          Sunny  ...
# 1                 27.0                    80.6  Partly cloudy  ...
# 2                 28.0                    82.4  Partly cloudy  ...
# 3                 10.2                    50.4          Sunny  ...
# 4                 25.0                    77.0  Partly cloudy  ...
# 5                 29.0                    84.2     Light rain  ...
# 6                  9.0                    48.2          Clear  ...
# 7                 31.0                    87.8  Partly cloudy  ...
# 8                 13.0                    55.4          Clear  ...
# 9                 16.0                    60.8     Light rain  ...
#
#    air_quality_us-epa-index  air_quality_gb-defra-index  sunrise   sunset  \
# 0                         1                           1  5:24 AM  6:24 PM
# 1                         2                           3  6:04 AM  7:19 PM
# 2                         1                           1  6:16 AM  7:21 PM
# 3                         1                           1  7:16 AM  8:34 PM
# 4                         4                          10  6:11 AM  6:06 PM
# 5                         1                           1  5:53 AM  6:23 PM
# 6                         1                           1  7:18 AM  6:34 PM
# 7                         1                           1  6:26 AM  7:39 PM
# 8                         1                           1  6:27 AM  5:42 PM
# 9                         1                           2  6:07 AM  7:43 PM
#
#    moonrise  moonset      moon_phase  moon_illumination  air_quality_class  \
# 0   5:39 PM  2:48 AM  Waxing Gibbous                 93               Good
# 1   6:50 PM  3:25 AM  Waxing Gibbous                 93               Good
# 2   6:46 PM  3:50 AM  Waxing Gibbous                 93               Good
# 3   8:08 PM  4:38 AM  Waxing Gibbous                 93               Good
# 4   4:43 PM  4:41 AM  Waxing Gibbous                 93          Unhealthy
# 5   5:36 PM  4:09 AM  Waxing Gibbous                 93               Good
# 6   4:57 PM  6:32 AM  Waxing Gibbous                 93               Good
# 7   7:05 PM  3:45 AM  Waxing Gibbous                 93               Good
# 8   3:19 PM  5:17 AM  Waxing Gibbous                 93               Good
# 9   7:27 PM  3:11 AM  Waxing Gibbous                 93               Good
#
#    predicted_air_quality_class
# 0                         Good
# 1                         Good
# 2                         Good
# 3                         Good
# 4                    Unhealthy
# 5                         Good
# 6                         Good
# 7                         Good
# 8                         Good
# 9                         Good
#
# [10 rows x 43 columns]

# %%
df.columns
# Out:
# Index(['country', 'location_name', 'latitude', 'longitude', 'timezone',
#        'last_updated_epoch', 'last_updated', 'temperature_celsius',
#        'temperature_fahrenheit', 'condition_text', 'wind_mph', 'wind_kph',
#        'wind_degree', 'wind_direction', 'pressure_mb', 'pressure_in',
#        'precip_mm', 'precip_in', 'humidity', 'cloud', 'feels_like_celsius',
#        'feels_like_fahrenheit', 'visibility_km', 'visibility_miles',
#        'uv_index', 'gust_mph', 'gust_kph', 'air_quality_Carbon_Monoxide',
#        'air_quality_Ozone', 'air_quality_Nitrogen_dioxide',
#        'air_quality_Sulphur_dioxide', 'air_quality_PM2.5', 'air_quality_PM10',
#        'air_quality_us-epa-index', 'air_quality_gb-defra-index', 'sunrise',
#        'sunset', 'moonrise', 'moonset', 'moon_phase', 'moon_illumination',
#        'air_quality_class', 'predicted_air_quality_class'],
#       dtype='object')

# %%
df.dtypes
# Out:
# country                          object
# location_name                    object
# latitude                        float64
# longitude                       float64
# timezone                         object
# last_updated_epoch                int64
# last_updated                     object
# temperature_celsius             float64
# temperature_fahrenheit          float64
# condition_text                   object
# wind_mph                        float64
# wind_kph                        float64
# wind_degree                       int64
# wind_direction                   object
# pressure_mb                       int64
# pressure_in                     float64
# precip_mm                       float64
# precip_in                       float64
# humidity                          int64
# cloud                             int64
# feels_like_celsius              float64
# feels_like_fahrenheit           float64
# visibility_km                   float64
# visibility_miles                  int64
# uv_index                          int64
# gust_mph                        float64
# gust_kph                        float64
# air_quality_Carbon_Monoxide     float64
# air_quality_Ozone               float64
# air_quality_Nitrogen_dioxide    float64
# air_quality_Sulphur_dioxide     float64
# air_quality_PM2.5               float64
# air_quality_PM10                float64
# air_quality_us-epa-index          int64
# air_quality_gb-defra-index        int64
# sunrise                          object
# sunset                           object
# moonrise                         object
# moonset                          object
# moon_phase                       object
# moon_illumination                 int64
# air_quality_class                object
# predicted_air_quality_class      object
# dtype: object

# %%
df.describe()
# Out:
#            latitude     longitude  last_updated_epoch  temperature_celsius  \
# count  27874.000000  27874.000000        2.787400e+04         27874.000000
# mean      19.297050     21.871075        1.699625e+09            19.219961
# std       24.565146     65.709383        3.778103e+06            10.425376
# min      -41.300000   -175.200000        1.693301e+09           -41.900000
# 25%        3.750000     -6.840000        1.696284e+09            13.000000
# 50%       17.250000     23.240000        1.699473e+09            22.000000
# 75%       41.330000     50.580000        1.703014e+09            27.000000
# max       64.100000    179.220000        1.706033e+09            45.400000
#
#        temperature_fahrenheit      wind_mph      wind_kph   wind_degree  \
# count            27874.000000  27874.000000  27874.000000  27874.000000
# mean                66.595849      7.137888     11.490030    161.318433
# std                 18.765930      5.138853      8.271526    106.761390
# min                -43.400000      2.200000      3.600000      1.000000
# 25%                 55.400000      3.600000      5.800000     70.000000
# 50%                 71.600000      5.600000      9.000000    150.000000
# 75%                 80.600000      9.400000     15.100000    250.000000
# max                113.700000     91.900000    148.000000    360.000000
#
#         pressure_mb   pressure_in  ...      gust_kph  \
# count  27874.000000  27874.000000  ...  27874.000000
# mean    1013.699613     29.933806  ...     19.028317
# std        7.350963      0.216951  ...     11.770780
# min      964.000000     28.470000  ...      0.000000
# 25%     1010.000000     29.830000  ...     10.400000
# 50%     1013.000000     29.910000  ...     16.600000
# 75%     1018.000000     30.060000  ...     25.400000
# max     1074.000000     31.710000  ...    155.200000
#
#        air_quality_Carbon_Monoxide  air_quality_Ozone  \
# count                 27874.000000       27874.000000
# mean                    588.158086          40.664770
# std                    1450.888670          31.546233
# min                      96.800000           0.000000
# 25%                     233.700000          16.500000
# 50%                     290.400000          37.900000
# 75%                     454.000000          59.400000
# max                   36315.898000         555.000000
#
#        air_quality_Nitrogen_dioxide  air_quality_Sulphur_dioxide  \
# count                  27874.000000                 27874.000000
# mean                      14.214964                     8.045594
# std                       26.214066                    21.753641
# min                        0.000000                     0.000000
# 25%                        1.100000                     0.500000
# 50%                        4.500000                     1.800000
# 75%                       15.400000                     6.375000
# max                      575.800000                   511.200000
#
#        air_quality_PM2.5  air_quality_PM10  air_quality_us-epa-index  \
# count       27874.000000      27874.000000              27874.000000
# mean           26.091157         45.660648                  1.621834
# std            67.901474        106.405538                  1.076234
# min             0.500000          0.500000                  1.000000
# 25%             2.500000          4.600000                  1.000000
# 50%             7.500000         12.900000                  1.000000
# 75%            23.300000         39.500000                  2.000000
# max          1558.800000       3566.400000                  6.000000
#
#        air_quality_gb-defra-index  moon_illumination
# count                27874.000000       27874.000000
# mean                     2.465165          50.080900
# std                      2.682353          34.984674
# min                      1.000000           0.000000
# 25%                      1.000000          15.000000
# 50%                      1.000000          49.000000
# 75%                      2.000000          86.000000
# max                     10.000000         100.000000
#
# [8 rows x 30 columns]

# %%
df.isnull().sum()
# Out:
# country                         0
# location_name                   0
# latitude                        0
# longitude                       0
# timezone                        0
# last_updated_epoch              0
# last_updated                    0
# temperature_celsius             0
# temperature_fahrenheit          0
# condition_text                  0
# wind_mph                        0
# wind_kph                        0
# wind_degree                     0
# wind_direction                  0
# pressure_mb                     0
# pressure_in                     0
# precip_mm                       0
# precip_in                       0
# humidity                        0
# cloud                           0
# feels_like_celsius              0
# feels_like_fahrenheit           0
# visibility_km                   0
# visibility_miles                0
# uv_index                        0
# gust_mph                        0
# gust_kph                        0
# air_quality_Carbon_Monoxide     0
# air_quality_Ozone               0
# air_quality_Nitrogen_dioxide    0
# air_quality_Sulphur_dioxide     0
# air_quality_PM2.5               0
# air_quality_PM10                0
# air_quality_us-epa-index        0
# air_quality_gb-defra-index      0
# sunrise                         0
# sunset                          0
# moonrise                        0
# moonset                         0
# moon_phase                      0
# moon_illumination               0
# air_quality_class               0
# predicted_air_quality_class     0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 27869    False
# 27870    False
# 27871    False
# 27872    False
# 27873    False
# Length: 27874, dtype: bool

# %%
numeric_data = df.select_dtypes(include=['int64', 'float64'])
correlation_matrix = numeric_data.corr()
plt.figure(figsize=(15, 10))
sns.heatmap(
    correlation_matrix,
    annot=True,
    fmt=".2f",
    cmap='coolwarm',
    cbar=True,
    annot_kws={"size": 8} 
)


plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.title('Correlation Matrix Heatmap', fontsize=14)  
plt.show()

# %%
numeric_data = df.select_dtypes(include=[ 'float64'])

# Calculate the correlation matrix
correlation_matrix = numeric_data.corr()

# Display the correlation matrix as a heatmap
plt.figure(figsize=(15,10 ))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', cbar=True)
plt.title('Correlation Matrix Heatmap')
plt.show()
